# %% [markdown]
# # 1. Go the the product homepage on Amazon.in

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 2. Go the reviews section at the bottom of the page and click on 'See all reviews'

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 3. Again go the bottom and go the second page by clicking 'Next page→'

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 4. Once on the 2nd page, kindly copy the url and replace the pageNumber value 2 with {x}

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 5. Kindly adjust other parameters like number of pages to scrape, number of reviews to save as per your need

# %% [markdown]
# <h1><center>Thank you!</center></h1>
